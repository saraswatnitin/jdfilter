# %%
import pandas as pd

# %%
import requests

# %%
auth_tokn=requests.get('https://api.jobdiva.com/api/authenticate',
                      params={'clientid':1245,
                              'username':'jobdiva.api@cogentinfo.com',
                             'password':'Pass@001'})

# %%
tokn=auth_tokn.text

csrf=requests.get('https://api.jobdiva.com/csrf')
csrf=csrf.text[10:46]


hdr={'Authorization':tokn,
        'X-CSRF-TOKEN': csrf}

# %%
hdr
# Out:
# {'Authorization': 'eyJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJqb2JkaXZhLmFwaUBjb2dlbnRpbmZvLmNvbSIsImV4cCI6MTY2MzE2MDgwNSwiaWF0IjoxNjYzMDc0NDA1fQ.9a_TRTkSQHkE3Cla5mWJwL8rEU2Nx2NnnH3-IGpsrbDDiR-mk2nCbGtx4BvvtE_Vl-o3NLgHplT-oK5Uk37bCA',
#  'X-CSRF-TOKEN': 'd933b2d5-17eb-455e-88b1-5dda2770da46'}

# %%
skill='.Net'
quoted_skill=str(skill)
    #skill='.Net'
print(skill)
urlquery='https://api.jobdiva.com/api/jobdiva/searchCandidateProfile?maxreturned=10&candidateQuals={"catId": 28,"dcatNames": "'+quoted_skill+'"}'
# Out:
# .Net

# %%
search_cand_prfl=requests.post(urlquery,
                                  headers=hdr
                                  #params=parms,
                                  #params=payload

                           )

# %%
#search_cand_prfl.content

# %%
#from io import BytesIO

# %%
searched_cand=pd.read_json(BytesIO(search_cand_prfl.content),orient='records')

#searched_cand=pd.DataFrame(pd.read_json(search_cand_prfl.text),index=[0])

# %%
df1 = searched_cand.replace({r'\s+$': '', r'^\s+': ''}, regex=True).replace(r'\n',  ' ', regex=True)

# %%
df1
# Out:
#               id    first name  middle initial   last name  \
# 0   215422831111      Adekunle             NaN     Adefela
# 1  9159254137246    Adil Nawaz             NaN        Syed
# 2  8843978364545        Ankita             NaN     Chauhan
# 3  8772370011200   Anoop Reddy             NaN  Katnapalli
# 4  6971761974239  Chandrakanth             NaN    Veggalam
# 5   433465119285         David             NaN     Whiting
# 6  9799784335157  Dinah Evonne             NaN       Sabbe
# 7  6787860834270       Geetika             NaN    Chillara
# 8  6847243716245      Gowthami             NaN   Dasireddy
#
#                           email        alternate email          address1  \
# 0            adefelak@gmail.com                   None              None
# 1            adil133k@gmail.com                   None              None
# 2    ankitachauhan166@gmail.com                   None              None
# 3    reddy.katnapalli@gmail.com                   None              None
# ...

# %%
#Use this /api/bi/CandidateResumesDetail
# to pull CandidateResumesDetail

# %%
{
  "message": "Query \"Candidate Resumes Detail\" completed successfully",
  "data": [
    {
      "CANDIDATEID": "9159254137246",
      "DOCID": "1",
      "DBID": "3",
      "RESUMEID": "9159254137246_1245_1",
      "DATECREATED": "2018-05-08 09:05:55.0",
      "DATEUPDATED": "2018-05-08 09:05:55.0",
      "DATEFIRSTDOWNLOADED": "2018-05-08 09:06:35.0",
      "DATELASTDOWNLOADED": "2018-05-08 09:06:35.0"
    }
  ]
}

# %%
# download base 64 encoded resume dat from      /api/bi/ResumeDetail
#ResumeDetail

# %%
import base64

# %%
# example string in base 64 format
base64_resume_string = '...'
# first convert string to ascii

# %%
#base64_img_bytes = base64_img.encode('utf-8')
ascii_bytes = base64_resume_string.encode('ISO-8859-1')
# then decode to base64 bytes
base64_bytes = base64.b64decode(ascii_bytes)
# decode by ascii, if needed

resume = base64_bytes.decode('ISO-8859-1')

# %%
type(resume)
# Out:
# str

# %%
resume
# Out:
# 'ÐÏ\x11à¡±\x1aá\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00>\x00\x03\x00þÿ\t\x00\x06\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\x00\x00\x00Ü\x00\x00\x00\x00\x00\x00\x00\x00\x10\x00\x00Þ\x00\x00\x00\x01\x00\x00\x00þÿÿÿ\x00\x00\x00\x00Ú\x00\x00\x00Û\x00\x00\x00ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿì¥Á\x00[\x80\t\x04\x00\x00ø\x12¿\x00\x00\x00\x00\x00\x00\x10\x00\x00\x00\x00\x00\x08\x00\x00\x13O\x00\x00\x0e\x00bjbj¬ú¬ú\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\t\x04\x16\x001¸\x00\x00Î\x90\x01\x00Î\x90\x01\x00óF\x00\x00\x00\x00\x00\x00\x1f\x00\x00\x00\
# ...
